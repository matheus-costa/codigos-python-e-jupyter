# %%
#IMPORTANDO AS BIBLIOTECAS QUE SERÃO USADAS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#Criando a variavel data, contendo a base de dados de cavalos
data = pd.read_csv("horse.csv")

#renomeando o  nome das colunas do database
data.columns = ['Surgery','Age','Hospital Number','Rectal Temperature','Pulse','Respiratory Rate','Temperature of Extremities','Peripheral Pulse','Mucous Membranes','Capillary Refill Time','Pain','Peristalsis','Abdominal Distension','Nasogastric Tube','Nasogastric Reflux','Nasogastric Reflux PH','Rectal Examination Feces','Abdomen','Packed Cell Volume','Total Protein','Abdominocentesis Appearance','Abdominocentesis Total Protein','Outcome','Surgical Lesion','Lesion Site','Lesion Type','Lesion Subtype','CP Data']

#Mostra as 5 primeiras linhas do dataFrame
data.head() # Show first 5 samples
# Out:
#   Surgery    Age  Hospital Number  Rectal Temperature  Pulse  \
# 0      no  adult           530101                38.5   66.0
# 1     yes  adult           534817                39.2   88.0
# 2      no  adult           530334                38.3   40.0
# 3     yes  young          5290409                39.1  164.0
# 4      no  adult           530255                37.3  104.0
#
#    Respiratory Rate Temperature of Extremities Peripheral Pulse  \
# 0              28.0                       cool          reduced
# 1              20.0                        NaN              NaN
# 2              24.0                     normal           normal
# 3              84.0                       cold           normal
# 4              35.0                        NaN              NaN
#
#   Mucous Membranes Capillary Refill Time  ... Packed Cell Volume  \
# 0              NaN            more_3_sec  ...               45.0
# 1    pale_cyanotic            less_3_sec  ...               50.0
# 2        pale_pink            less_3_sec  ...               33.0
# 3    dark_cyanotic            more_3_sec  ...               48.0
# 4    dark_cyanotic            more_3_sec  ...               74.0
#
#   Total Protein Abdominocentesis Appearance Abdominocentesis Total Protein  \
# 0           8.4                         NaN                            NaN
# 1          85.0                      cloudy                            2.0
# 2           6.7                         NaN                            NaN
# 3           7.2               serosanguious                            5.3
# 4           7.4                         NaN                            NaN
#
#       Outcome  Surgical Lesion Lesion Site Lesion Type  Lesion Subtype  \
# 0        died               no       11300           0               0
# 1  euthanized               no        2208           0               0
# 2       lived               no           0           0               0
# 3        died              yes        2208           0               0
# 4        died               no        4300           0               0
#
#    CP Data
# 0       no
# 1       no
# 2      yes
# 3      yes
# 4       no
#
# [5 rows x 28 columns]

# %%
#mostrando o tipo de variável/ valor que tem em cada coluna do database
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Surgery                         299 non-null    object
#  1   Age                             299 non-null    object
#  2   Hospital Number                 299 non-null    int64
#  3   Rectal Temperature              239 non-null    float64
#  4   Pulse                           275 non-null    float64
#  5   Respiratory Rate                241 non-null    float64
#  6   Temperature of Extremities      243 non-null    object
#  7   Peripheral Pulse                230 non-null    object
#  8   Mucous Membranes                252 non-null    object
#  9   Capillary Refill Time           267 non-null    object
#  10  Pain                            244 non-null    object
#  11  Peristalsis                     255 non-null    object
#  12  Abdominal Distension            243 non-null    object
#  13  Nasogastric Tube                195 non-null    object
#  14  Nasogastric Reflux              193 non-null    object
#  15  Nasogastric Reflux PH           53 non-null     float64
#  16  Rectal Examination Feces        197 non-null    object
#  17  Abdomen                         181 non-null    object
#  18  Packed Cell Volume              270 non-null    float64
#  19  Total Protein                   266 non-null    float64
#  20  Abdominocentesis Appearance     134 non-null    object
#  21  Abdominocentesis Total Protein  101 non-null    float64
#  22  Outcome                         299 non-null    object
#  23  Surgical Lesion                 299 non-null    object
#  24  Lesion Site                     299 non-null    int64
#  25  Lesion Type                     299 non-null    int64
#  26  Lesion Subtype                  299 non-null    int64
#  27  CP Data                         299 non-null    object
# dtypes: float64(7), int64(4), object(17)
# memory usage: 65.5+ KB

# %%
#mostrando os valores nulos do database
data.isnull().sum()
# Out:
# Surgery                             0
# Age                                 0
# Hospital Number                     0
# Rectal Temperature                 60
# Pulse                              24
# Respiratory Rate                   58
# Temperature of Extremities         56
# Peripheral Pulse                   69
# Mucous Membranes                   47
# Capillary Refill Time              32
# Pain                               55
# Peristalsis                        44
# Abdominal Distension               56
# Nasogastric Tube                  104
# Nasogastric Reflux                106
# Nasogastric Reflux PH             246
# Rectal Examination Feces          102
# Abdomen                           118
# Packed Cell Volume                 29
# Total Protein                      33
# Abdominocentesis Appearance       165
# Abdominocentesis Total Protein    198
# Outcome                             0
# Surgical Lesion                     0
# Lesion Site                         0
# Lesion Type                         0
# Lesion Subtype                      0
# CP Data                             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
#usando label enconder para converter as variáveis categoricas
encoder = LabelEncoder()

data['Surgery'] = encoder.fit_transform(data['Surgery'])
data['Age'] = encoder.fit_transform(data['Age'])
data['Temperature of Extremities'] = encoder.fit_transform(data['Temperature of Extremities'])
data['Peripheral Pulse'] = encoder.fit_transform(data['Peripheral Pulse'])
data['Mucous Membranes'] = encoder.fit_transform(data['Mucous Membranes'])
data['Capillary Refill Time'] = encoder.fit_transform(data['Capillary Refill Time'])
data['Pain'] = encoder.fit_transform(data['Pain'])
data['Peristalsis'] = encoder.fit_transform(data['Peristalsis'])
data['Abdominal Distension'] = encoder.fit_transform(data['Abdominal Distension'])
data['Nasogastric Tube'] = encoder.fit_transform(data['Nasogastric Tube'])
data['Nasogastric Reflux'] = encoder.fit_transform(data['Nasogastric Reflux'])
data['Rectal Examination Feces'] = encoder.fit_transform(data['Rectal Examination Feces'])
data['Abdomen'] = encoder.fit_transform(data['Abdomen'])
data['Abdominocentesis Appearance'] = encoder.fit_transform(data['Abdominocentesis Appearance'])
data['Outcome'] = encoder.fit_transform(data['Outcome'])
data['Surgical Lesion'] = encoder.fit_transform(data['Surgical Lesion'])
data['CP Data'] = encoder.fit_transform(data['CP Data'])

data.head()
# Out:
#    Surgery  Age  Hospital Number  Rectal Temperature  Pulse  Respiratory Rate  \
# 0        0    0           530101                38.5   66.0              28.0
# 1        1    0           534817                39.2   88.0              20.0
# 2        0    0           530334                38.3   40.0              24.0
# 3        1    1          5290409                39.1  164.0              84.0
# 4        0    0           530255                37.3  104.0              35.0
#
#    Temperature of Extremities  Peripheral Pulse  Mucous Membranes  \
# 0                           1                 3                 6
# 1                           4                 4                 4
# 2                           2                 2                 5
# 3                           0                 2                 2
# 4                           4                 4                 2
#
#    Capillary Refill Time  ...  Packed Cell Volume  Total Protein  \
# 0                      2  ...                45.0            8.4
# 1                      1  ...                50.0           85.0
# 2                      1  ...                33.0            6.7
# 3                      2  ...                48.0            7.2
# 4                      2  ...                74.0            7.4
#
#    Abdominocentesis Appearance  Abdominocentesis Total Protein  Outcome  \
# 0                            3                             NaN        0
# 1                            1                             2.0        1
# 2                            3                             NaN        2
# 3                            2                             5.3        0
# 4                            3                             NaN        0
#
#    Surgical Lesion  Lesion Site  Lesion Type  Lesion Subtype  CP Data
# 0                0        11300            0               0        0
# 1                0         2208            0               0        0
# 2                0            0            0               0        1
# 3                1         2208            0               0        1
# 4                0         4300            0               0        0
#
# [5 rows x 28 columns]

# %%
from sklearn.impute import SimpleImputer

# %%
# Cria o imputador que preenche NaN com a média dos dados
imputer = SimpleImputer(strategy='mean')
# Aplica imputação
X_imputado = imputer.fit_transform(data)
X_imputado = pd.DataFrame(X_imputado, columns=data.columns)
#verifica os NAN
print(X_imputado.isnull().sum())

data = X_imputado
# Out:
# Surgery                           0
# Age                               0
# Hospital Number                   0
# Rectal Temperature                0
# Pulse                             0
# Respiratory Rate                  0
# Temperature of Extremities        0
# Peripheral Pulse                  0
# Mucous Membranes                  0
# Capillary Refill Time             0
# Pain                              0
# Peristalsis                       0
# Abdominal Distension              0
# Nasogastric Tube                  0
# Nasogastric Reflux                0
# Nasogastric Reflux PH             0
# Rectal Examination Feces          0
# Abdomen                           0
# Packed Cell Volume                0
# Total Protein                     0
# Abdominocentesis Appearance       0
# Abdominocentesis Total Protein    0
# Outcome                           0
# Surgical Lesion                   0
# Lesion Site                       0
# Lesion Type                       0
# Lesion Subtype                    0
# CP Data                           0
# dtype: int64

# %%
#mostrando o tipo de variável/ valor que tem em cada coluna do database
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Surgery                         299 non-null    float64
#  1   Age                             299 non-null    float64
#  2   Hospital Number                 299 non-null    float64
#  3   Rectal Temperature              299 non-null    float64
#  4   Pulse                           299 non-null    float64
#  5   Respiratory Rate                299 non-null    float64
#  6   Temperature of Extremities      299 non-null    float64
#  7   Peripheral Pulse                299 non-null    float64
#  8   Mucous Membranes                299 non-null    float64
#  9   Capillary Refill Time           299 non-null    float64
#  10  Pain                            299 non-null    float64
#  11  Peristalsis                     299 non-null    float64
#  12  Abdominal Distension            299 non-null    float64
#  13  Nasogastric Tube                299 non-null    float64
#  14  Nasogastric Reflux              299 non-null    float64
#  15  Nasogastric Reflux PH           299 non-null    float64
#  16  Rectal Examination Feces        299 non-null    float64
#  17  Abdomen                         299 non-null    float64
#  18  Packed Cell Volume              299 non-null    float64
#  19  Total Protein                   299 non-null    float64
#  20  Abdominocentesis Appearance     299 non-null    float64
#  21  Abdominocentesis Total Protein  299 non-null    float64
#  22  Outcome                         299 non-null    float64
#  23  Surgical Lesion                 299 non-null    float64
#  24  Lesion Site                     299 non-null    float64
#  25  Lesion Type                     299 non-null    float64
#  26  Lesion Subtype                  299 non-null    float64
#  27  CP Data                         299 non-null    float64
# dtypes: float64(28)
# memory usage: 65.5 KB

# %%
# Data must be in numpy.ndarray format
x = data.iloc[:,0:25] # columns from 1 to 11 are the inputs (x)
col = x.columns #store column names
x = x.to_numpy() # Convert to numpy.ndarray
y = data['Surgery'] # column FWI is the output (y)
y = y.to_numpy() # Convert to numpy.ndarray

# %%
from sklearn import linear_model
from sklearn import metrics

regr = linear_model.LinearRegression()
regr.fit(x, y)

pred = regr.predict(x)

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.4f" % metrics.mean_squared_error(y, pred))
print("Correlation Coefficient: %.4f " % np.corrcoef(y, pred)[0,1])
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.4f" % metrics.r2_score(y, pred))
# Out:
# Coefficients:
#  [ 1.00000000e+00  2.00498227e-16 -9.96970825e-22  1.23178053e-16
#  -2.27526766e-17 -2.05999394e-17  3.21880574e-16  1.92383617e-16
#  -9.93343946e-17 -1.12718835e-16 -6.34625016e-17 -2.39778365e-16
#   8.69117750e-18 -1.23446870e-16  1.21198592e-17  1.67858069e-16
#   6.24806141e-17  1.42596653e-16 -2.07100560e-17  2.45329500e-17
#   9.13415025e-17 -9.36363427e-17  1.00440389e-16  1.03945112e-15
#   1.97593313e-19]
# Mean squared error: 0.0000
# Correlation Coefficient: 1.0000
# Coefficient of determination: 1.0000

# %%
# Plot model outputs
plt.scatter(y, pred, color="blue")
plt.plot([-5,35], [-5,35], color = 'black', ls = '--')
plt.xlabel("Real surgery")
plt.ylabel("Predicted surgery")
plt.title("Correlation Coefficient: %.4f" % np.corrcoef(y, pred)[0,1])
plt.show()

# %%
# Correlation coefficients of inputs
plt.barh(col, regr.coef_, align='center')
plt.xlabel("Regression Coefficients")
plt.ylabel("Inputs")
plt.title("FWI Linear Regression Model")
# Out:
# Text(0.5, 1.0, 'FWI Linear Regression Model')

# %%
plt.scatter(x[:,24],y)
plt.xlabel("ISI")
plt.ylabel("FWI")
plt.title("Correlation Coefficient: %.4f" % np.corrcoef(x[:,10], y)[0,1])
# Out:
# Text(0.5, 1.0, 'Correlation Coefficient: 0.2051')

# %%
plt.scatter(x[:,11],y)
plt.xlabel("BUI")
plt.ylabel("FWI")
plt.title("Correlation Coefficient: %.4f" % np.corrcoef(x[:,11], y)[0,1])
# Out:
# Text(0.5, 1.0, 'Correlation Coefficient: -0.0593')

# %%
plt.scatter(x[:,5],y)
plt.xlabel("RH")
plt.ylabel("FWI")
plt.title("Correlation Coefficient: %.4f" % np.corrcoef(x[:,5], y)[0,1])
# Out:
# Text(0.5, 1.0, 'Correlation Coefficient: 0.1812')
